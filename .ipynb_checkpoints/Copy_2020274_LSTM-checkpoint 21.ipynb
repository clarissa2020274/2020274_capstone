# %% [markdown]
# ## Predictive Insights in the Coffee Market: Time Series Models for forecasting of coffee in the commodity stock market
#
#
# Student id: 2020274 Clarissa Cardoso
#
#
#
# ## Introduction
#
# This notebook will present the data preparation for forecasting models SARIMA and LSTM for the coffee price prediction project based on the ICIP values published by the ICO.
#
# ### Dataset:
#
# The dataset used in this analysis consists of historical coffee price data, with daily observations for business days. Prices are expressed in cents of USD per lb. and stated on a
# differential basis to the New York and London futures exchanges (https://icocoffee.org/wp-content/uploads/2023/01/icc-105-17-r1e-rules-indicator-prices.pdf)
#
# The data utilized in this project is sourced from the International Coffee Organization's (ICO) Public Market Information (https://ico.org/resources/public-market-information/), which provides the I-CIP values free of charge.
#
# For the early stages of the experimentation, 1 year worth of data was available to collect, from 01Feb23 to 29Feb24, which is present on a separate notebook (2020274_capstone_EDA_Models 2.ipynb). In the side notebook [2020274_October_24_Data cleaning and EDA_version1] recent data from March to September 2024 were added to expand insights and feed more datapoints to this modelling stage.

# %%
#importing libraries
import warnings
warnings.filterwarnings("ignore")

import pandas as pd #dataframes 
import numpy as np #linear algebra
import seaborn as sns #visualization
sns.set(color_codes=True)


import plotly.express as px
import plotly.graph_objects as go


import scipy.stats as stats #statistical resources

import matplotlib.pyplot as plt #visualisation 
# %matplotlib inline 


from matplotlib import colors
from matplotlib.ticker import PercentFormatter
import matplotlib as mpl

from sklearn.model_selection import train_test_split # importing function to split the data training and test.
from sklearn.preprocessing import MinMaxScaler # Import the MinMaxScaler module from sklearn.preprocessing library
from sklearn.linear_model import LinearRegression # importing to performe linear regression. 
from sklearn.metrics import make_scorer, r2_score # Importing from Metrics module
from sklearn.preprocessing import StandardScaler # standardize the data
from sklearn import metrics # Metrics module from scikit-learn
from sklearn.model_selection import GridSearchCV # importing for hyperparameter tunning
from sklearn.metrics import mean_squared_error # importing mse
from scipy.stats import shapiro

from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential #last update in python causing dead kernel wehn importing keras functions?
from keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
from keras.optimizers import SGD
import math
from math import sqrt
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from scipy.interpolate import interp1d

from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import TimeSeriesSplit



from statsmodels.tsa.stattools import adfuller
import statsmodels.api as sm
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %% [markdown]
# ## Libraries for Deep Learning

# %%
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, GRU, Flatten, Dropout, Lambda

import tensorflow as tf
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Loading data
# Using dataframe with pre-processed data on separate Jupyter Notebook
#
#
# 433 rows containing original prices, standardised prices, normalised, differentiated values and 4 time-based features (DayOfWeek	|WeekOfYear	|Month	|Quarter)

# %%
df = pd.read_csv('processed_data.csv', index_col='date', parse_dates=True)

# %%
df
# Out:
#              I-CIP  price_standardized  price_normalized  price_diff  \
# date
# 2023-02-02  172.50           -0.482921          0.209218        1.07
# 2023-02-03  169.47           -0.578568          0.185305       -3.03
# 2023-02-06  171.29           -0.521117          0.199669        1.82
# 2023-02-07  172.14           -0.494285          0.206377        0.85
# 2023-02-08  171.23           -0.523011          0.199195       -0.91
# ...            ...                 ...               ...         ...
# 2024-09-24  269.83            2.589469          0.977350        3.05
# 2024-09-25  270.09            2.597677          0.979402        0.26
# 2024-09-26  272.70            2.680066          1.000000        2.61
# 2024-09-27  268.97            2.562322          0.970563       -3.73
# 2024-09-30  270.37            2.606515          0.981612        1.40
#
#             I-CIP_Standardised
# date
# 2023-02-02            0.209218
# 2023-02-03            0.185305
# 2023-02-06            0.199669
# 2023-02-07            0.206377
# 2023-02-08            0.199195
# ...                        ...
# 2024-09-24            0.977350
# 2024-09-25            0.979402
# 2024-09-26            1.000000
# 2024-09-27            0.970563
# 2024-09-30            0.981612
#
# [433 rows x 5 columns]

# %%
# Select the target column for time series analysis
target_col = 'I-CIP'

# Plot the time series
plt.figure(figsize=(12, 6))
plt.plot(df[target_col], label='Composite Inidicator Prices')
plt.title('Time Series')
plt.xlabel('Date')
plt.ylabel('Original Prices from ICO Composite')
plt.legend()
plt.show()

# %% [markdown]
# ## 2. Data prep for LSTM
#
#
# ### 2.1 Cheking for stationarity
#  for both normalised data (will mantain data structure, but only in a smaller scale from 0 to 1) and diff values

# %%
# ADF Test for Stationarity
result = adfuller(df[target_col])
print("ADF Test Statistic:", result[0])
print("p-value:", result[1])
print("Critical Values:", result[4])
# Out:
# ADF Test Statistic: 1.659357789393701
# p-value: 0.9980251657535799
# Critical Values: {'1%': -3.446205926287236, '5%': -2.8685297226414734, '10%': -2.570493298011322}

# %%
# Select the target column for SARIMA using ICIP prices
df_sarima = df[['I-CIP']]

# %% [markdown]
# #### Shapiro-Wilk test for normality of  icip

# %%
from scipy.stats import shapiro

def check_normality(series):
    stat, p_value = shapiro(series)
    print(f'Shapiro-Wilk Test Statistic: {stat}')
    print(f'p-value: {p_value}')

    if p_value < 0.05:
        print("The data does not appear to be normally distributed.")
    else:
        print("The data appears to be normally distributed.")

# check function
check_normality(df_sarima)
# Out:
# Shapiro-Wilk Test Statistic: 0.8879902362823486
# p-value: 3.189733842585338e-17
# The data does not appear to be normally distributed.

# %%
# check function
check_normality(df['price_diff'])
# Out:
# Shapiro-Wilk Test Statistic: 0.9792444109916687
# p-value: 7.385493972833501e-06
# The data does not appear to be normally distributed.

# %%
# checkin stationarity for diff prices
def check_stationarity(series):
    result = adfuller(series, autolag='AIC')
    print(f'ADF Statistic: {result[0]}')
    print(f'p-value: {result[1]}')
    for key, value in result[4].items():
        print(f'Critical Value {key}: {value}')

check_stationarity(df_sarima)
# Out:
# ADF Statistic: 1.659357789393701
# p-value: 0.9980251657535799
# Critical Value 1%: -3.446205926287236
# Critical Value 5%: -2.8685297226414734
# Critical Value 10%: -2.570493298011322

# %%
# checkin stationarity for diff prices
def check_stationarity(series):
    result = adfuller(series, autolag='AIC')
    print(f'ADF Statistic: {result[0]}')
    print(f'p-value: {result[1]}')
    for key, value in result[4].items():
        print(f'Critical Value {key}: {value}')

check_stationarity(df_sarima)
# Out:
# ADF Statistic: 1.659357789393701
# p-value: 0.9980251657535799
# Critical Value 1%: -3.446205926287236
# Critical Value 5%: -2.8685297226414734
# Critical Value 10%: -2.570493298011322

# %%
# Drop NaN values caused by differentiation (from 434 to 433 total obs)
df_sarima = df_sarima.dropna()

# Display the cleaned data
print(df_sarima.head())
# Out:
#              I-CIP
# date
# 2023-02-02  172.50
# 2023-02-03  169.47
# 2023-02-06  171.29
# 2023-02-07  172.14
# 2023-02-08  171.23

# %%
df_sarima.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 433 entries, 2023-02-02 to 2024-09-30
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   I-CIP   433 non-null    float64
# dtypes: float64(1)
# memory usage: 6.8 KB

# %% [markdown]
# Checking Differentiated prices time series shape

# %%
# Plot the differentiated series
plt.figure(figsize=(12, 6))
plt.plot(df['price_diff'], label='Differentiated Price')
plt.title('Differentiated Time Series')
plt.xlabel('Date')
plt.ylabel('Price Difference')
plt.legend()
plt.show()

# %%
#acf plot for correlation
plot_acf(df['price_diff'].dropna())
plt.show()

# partial correlation 
plot_pacf(df['price_diff'].dropna())
plt.show()

# %% [markdown]
#  ## Build dictionary to store all metrics from the modeling

# %%
# Initialise a dictionary to store error metrics
model_results = {}

# Function to add new results to the dictionary
def add_model_results(model_name, mse, mae, rmse):
    """
    Adds model performance metrics to the results dictionary.
    """
    model_results[model_name] = {
        'MSE': mse,
        'MAE': mae,
        'RMSE': rmse,
    }

# Example: Adding a placeholder for Linear Regression results
add_model_results("Linear Regression", mse=0.0037, mae=0.0469, rmse=0.0612)

# Print the initial dictionary
print("Initial Model Results:")
print(model_results)
# Out:
# Initial Model Results:
# {'Linear Regression': {'MSE': 0.0037, 'MAE': 0.0469, 'RMSE': 0.0612}}

# %%
df_sarima
# Out:
#              I-CIP
# date
# 2023-02-02  172.50
# 2023-02-03  169.47
# 2023-02-06  171.29
# 2023-02-07  172.14
# 2023-02-08  171.23
# ...            ...
# 2024-09-24  269.83
# 2024-09-25  270.09
# 2024-09-26  272.70
# 2024-09-27  268.97
# 2024-09-30  270.37
#
# [433 rows x 1 columns]

# %% [markdown]
# ## LSTM - Long Term Short Memory
#
#
# "Neural Networks are very complex machine learning models that pass input data through a network. Each node in the network learns a very simple operation. The neural network consists of many such nodes. The fact that the model can use a large number of simple nodes makes the overall prediction very complex. Neural Networks can therefore fit very complex and nonlinear data sets.  This can be useful for multiple use cases, including understanding time series (which are clearly sequences of values over time), but also text (sentences are sequences of words).
#
# LSTMs are a specific type of RNNs. They have proven useful for time series forecasting on multiple occasions. They require some data and are more complicated to learn than supervised models. Once you master them, they can prove to be very powerful depending on your data and your specific use case." https://neptune.ai/blog/select-model-for-time-series-prediction-task
#
# <i> "Long Short-Term Memory Networks is a deep learning, sequential neural network that allows information to persist. It is a special type of Recurrent Neural Network which is capable of handling the vanishing gradient problem faced by RNN. LSTM was designed by Hochreiter and Schmidhuber that resolves the problem caused by traditional rnns and machine learning algorithms. LSTM Model can be implemented in Python using the Keras library."
# (Saxena,2024)
#
#
#     - ideal for prediction tasks
#
#
#
# <b>The Logic Behind LSTM</b>
#
# ![download%20%282%29.png](attachment:download%20%282%29.png)
#
#
#     The first part chooses whether the information coming from the previous timestamp is to be remembered or is irrelevant and can be forgotten. In the second part, the cell tries to learn new information from the input to this cell. At last, in the third part, the cell passes the updated information from the current timestamp to the next timestamp. This one cycle of LSTM is considered a single-time step.
#
#
#     . Neural Networks can therefore fit very complex and nonlinear data sets.
#
# https://www.analyticsvidhya.com/blog/2021/03/introduction-to-long-short-term-memory-lstm/

# %% [markdown]
# ### LSTM requires data to be scaled for better performance and avoiding under/overfitting.
#
# The normalised prices were calculated with a min max scaler from 0-1, based on the mean and std variance, it is the common practice for this kind of modeling.
#
#
# https://medium.com/@iqra1804/time-series-forecasting-using-lstm-an-introduction-with-code-explanations-c5c2e8ca137d

# %%
# 
# Using only 'price_normalized' as a feature for simplicity

# Reshape the features to [samples, time steps, features]
X = np.array(df['price_normalized']).reshape(-1, 1, 1)
y = df['price_normalized']

# %% [markdown]
# ## LSTM (1)
# ### Splitting train/test

# %%
# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %% [markdown]
# ### Building a simple version of the model with a single layer

# %%
# Build the LSTM model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(1, 1)))
model.add(LSTM(units=50))
model.add(Dense(1))

# %% [markdown]
# ### Compiling and training the model

# %%
import time
# Start timing
start_time = time.time()



# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.1)

# End timing
end_time = time.time()
elapsed_time = end_time - start_time
print(f"LSTM running time: {elapsed_time:.2f} seconds")
## https://stackoverflow.com/questions/66576876/nameerror-name-history-is-not-defined
# Out:
# Epoch 1/100
# 10/10 [==============================] - 2s 69ms/step - loss: 0.0409 - val_loss: 0.2491
# Epoch 2/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0273 - val_loss: 0.1940
# Epoch 3/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0157 - val_loss: 0.1357
# Epoch 4/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0088 - val_loss: 0.0861
# Epoch 5/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0075 - val_loss: 0.0661
# Epoch 6/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0072 - val_loss: 0.0720
# Epoch 7/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0065 - val_loss: 0.0743
# Epoch 8/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0059 - val_loss: 0.0647
# Epoch 9/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0053 - val_loss: 0.0530
# Epoch 10/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0047 - val_loss: 0.0454
# Epoch 11/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0040 - val_loss: 0.0356
# Epoch 12/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0032 - val_loss: 0.0275
# Epoch 13/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0025 - val_loss: 0.0174
# Epoch 14/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0017 - val_loss: 0.0099
# Epoch 15/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0011 - val_loss: 0.0043
# Epoch 16/100
# 10/10 [==============================] - 0s 5ms/step - loss: 6.1951e-04 - val_loss: 8.8620e-04
# Epoch 17/100
# 10/10 [==============================] - 0s 4ms/step - loss: 2.9700e-04 - val_loss: 1.0753e-04
# Epoch 18/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1496e-04 - val_loss: 8.4788e-04
# Epoch 19/100
# 10/10 [==============================] - 0s 6ms/step - loss: 4.9956e-05 - val_loss: 0.0016
# Epoch 20/100
# 10/10 [==============================] - 0s 18ms/step - loss: 3.4653e-05 - val_loss: 0.0027
# Epoch 21/100
# 10/10 [==============================] - 0s 11ms/step - loss: 3.5089e-05 - val_loss: 0.0027
# Epoch 22/100
# 10/10 [==============================] - 0s 9ms/step - loss: 3.4084e-05 - val_loss: 0.0026
# Epoch 23/100
# 10/10 [==============================] - 0s 8ms/step - loss: 3.2468e-05 - val_loss: 0.0025
# Epoch 24/100
# 10/10 [==============================] - 0s 8ms/step - loss: 3.1630e-05 - val_loss: 0.0024
# Epoch 25/100
# 10/10 [==============================] - 0s 7ms/step - loss: 3.1237e-05 - val_loss: 0.0022
# Epoch 26/100
# 10/10 [==============================] - 0s 7ms/step - loss: 3.0739e-05 - val_loss: 0.0022
# Epoch 27/100
# 10/10 [==============================] - 0s 7ms/step - loss: 2.9948e-05 - val_loss: 0.0020
# Epoch 28/100
# 10/10 [==============================] - 0s 6ms/step - loss: 2.9641e-05 - val_loss: 0.0020
# Epoch 29/100
# 10/10 [==============================] - 0s 6ms/step - loss: 2.8635e-05 - val_loss: 0.0021
# Epoch 30/100
# 10/10 [==============================] - 0s 6ms/step - loss: 2.8358e-05 - val_loss: 0.0020
# Epoch 31/100
# 10/10 [==============================] - 0s 5ms/step - loss: 2.7660e-05 - val_loss: 0.0020
# Epoch 32/100
# 10/10 [==============================] - 0s 4ms/step - loss: 2.6827e-05 - val_loss: 0.0019
# Epoch 33/100
# 10/10 [==============================] - 0s 4ms/step - loss: 2.6928e-05 - val_loss: 0.0019
# Epoch 34/100
# 10/10 [==============================] - 0s 6ms/step - loss: 2.6136e-05 - val_loss: 0.0018
# Epoch 35/100
# 10/10 [==============================] - 0s 4ms/step - loss: 2.5701e-05 - val_loss: 0.0018
# Epoch 36/100
# 10/10 [==============================] - 0s 4ms/step - loss: 2.5066e-05 - val_loss: 0.0018
# Epoch 37/100
# 10/10 [==============================] - 0s 4ms/step - loss: 2.4804e-05 - val_loss: 0.0018
# Epoch 38/100
# 10/10 [==============================] - 0s 4ms/step - loss: 2.3950e-05 - val_loss: 0.0017
# Epoch 39/100
# 10/10 [==============================] - 0s 4ms/step - loss: 2.4241e-05 - val_loss: 0.0016
# Epoch 40/100
# 10/10 [==============================] - 0s 4ms/step - loss: 2.2638e-05 - val_loss: 0.0016
# Epoch 41/100
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1960e-05 - val_loss: 0.0016
# Epoch 42/100
# 10/10 [==============================] - 0s 4ms/step - loss: 2.2257e-05 - val_loss: 0.0014
# Epoch 43/100
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1354e-05 - val_loss: 0.0016
# Epoch 44/100
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0854e-05 - val_loss: 0.0014
# Epoch 45/100
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0157e-05 - val_loss: 0.0013
# Epoch 46/100
# 10/10 [==============================] - 0s 3ms/step - loss: 2.0061e-05 - val_loss: 0.0014
# Epoch 47/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.9858e-05 - val_loss: 0.0013
# Epoch 48/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8921e-05 - val_loss: 0.0012
# Epoch 49/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8456e-05 - val_loss: 0.0012
# Epoch 50/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.7387e-05 - val_loss: 0.0011
# Epoch 51/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.7809e-05 - val_loss: 0.0011
# Epoch 52/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.7399e-05 - val_loss: 0.0011
# Epoch 53/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.5977e-05 - val_loss: 0.0010
# Epoch 54/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.5801e-05 - val_loss: 0.0011
# Epoch 55/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.5295e-05 - val_loss: 0.0010
# Epoch 56/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.5620e-05 - val_loss: 8.5835e-04
# Epoch 57/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.4113e-05 - val_loss: 9.8394e-04
# Epoch 58/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3618e-05 - val_loss: 9.1111e-04
# Epoch 59/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3534e-05 - val_loss: 8.8865e-04
# Epoch 60/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.2973e-05 - val_loss: 8.2809e-04
# Epoch 61/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.2292e-05 - val_loss: 8.2392e-04
# Epoch 62/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1982e-05 - val_loss: 8.0021e-04
# Epoch 63/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1661e-05 - val_loss: 7.9780e-04
# Epoch 64/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1216e-05 - val_loss: 7.3997e-04
# Epoch 65/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.1838e-05 - val_loss: 8.3185e-04
# Epoch 66/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.1770e-05 - val_loss: 6.5883e-04
# Epoch 67/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.0652e-05 - val_loss: 6.0638e-04
# Epoch 68/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.0031e-05 - val_loss: 6.2991e-04
# Epoch 69/100
# 10/10 [==============================] - 0s 4ms/step - loss: 9.5080e-06 - val_loss: 5.9546e-04
# Epoch 70/100
# 10/10 [==============================] - 0s 4ms/step - loss: 9.1426e-06 - val_loss: 6.2038e-04
# Epoch 71/100
# 10/10 [==============================] - 0s 3ms/step - loss: 8.8956e-06 - val_loss: 5.3381e-04
# Epoch 72/100
# 10/10 [==============================] - 0s 4ms/step - loss: 8.8971e-06 - val_loss: 5.8710e-04
# Epoch 73/100
# 10/10 [==============================] - 0s 10ms/step - loss: 8.3958e-06 - val_loss: 5.3951e-04
# Epoch 74/100
# 10/10 [==============================] - 0s 4ms/step - loss: 8.0498e-06 - val_loss: 4.9749e-04
# Epoch 75/100
# 10/10 [==============================] - 0s 5ms/step - loss: 7.6283e-06 - val_loss: 4.9695e-04
# Epoch 76/100
# 10/10 [==============================] - 0s 4ms/step - loss: 7.5573e-06 - val_loss: 5.0152e-04
# Epoch 77/100
# 10/10 [==============================] - 0s 4ms/step - loss: 7.2409e-06 - val_loss: 4.7927e-04
# Epoch 78/100
# 10/10 [==============================] - 0s 4ms/step - loss: 7.1142e-06 - val_loss: 4.0485e-04
# Epoch 79/100
# 10/10 [==============================] - 0s 4ms/step - loss: 6.7340e-06 - val_loss: 4.0340e-04
# Epoch 80/100
# 10/10 [==============================] - 0s 4ms/step - loss: 7.0595e-06 - val_loss: 4.5466e-04
# Epoch 81/100
# 10/10 [==============================] - 0s 4ms/step - loss: 6.4256e-06 - val_loss: 3.8380e-04
# Epoch 82/100
# 10/10 [==============================] - 0s 4ms/step - loss: 5.9883e-06 - val_loss: 3.5365e-04
# Epoch 83/100
# 10/10 [==============================] - 0s 4ms/step - loss: 5.6063e-06 - val_loss: 3.7716e-04
# Epoch 84/100
# 10/10 [==============================] - 0s 4ms/step - loss: 5.8021e-06 - val_loss: 3.3442e-04
# Epoch 85/100
# 10/10 [==============================] - 0s 4ms/step - loss: 5.3133e-06 - val_loss: 2.9525e-04
# Epoch 86/100
# 10/10 [==============================] - 0s 3ms/step - loss: 5.0796e-06 - val_loss: 3.1509e-04
# Epoch 87/100
# 10/10 [==============================] - 0s 3ms/step - loss: 4.8518e-06 - val_loss: 2.7785e-04
# Epoch 88/100
# 10/10 [==============================] - 0s 3ms/step - loss: 4.6339e-06 - val_loss: 2.7922e-04
# Epoch 89/100
# 10/10 [==============================] - 0s 3ms/step - loss: 4.3977e-06 - val_loss: 2.6156e-04
# Epoch 90/100
# 10/10 [==============================] - 0s 4ms/step - loss: 4.1974e-06 - val_loss: 2.6189e-04
# Epoch 91/100
# 10/10 [==============================] - 0s 4ms/step - loss: 4.0336e-06 - val_loss: 2.4153e-04
# Epoch 92/100
# 10/10 [==============================] - 0s 4ms/step - loss: 3.9123e-06 - val_loss: 2.3791e-04
# Epoch 93/100
# 10/10 [==============================] - 0s 4ms/step - loss: 3.7476e-06 - val_loss: 2.1993e-04
# Epoch 94/100
# 10/10 [==============================] - 0s 4ms/step - loss: 3.5622e-06 - val_loss: 2.1425e-04
# Epoch 95/100
# 10/10 [==============================] - 0s 4ms/step - loss: 3.6386e-06 - val_loss: 2.3576e-04
# Epoch 96/100
# 10/10 [==============================] - 0s 4ms/step - loss: 3.4001e-06 - val_loss: 1.9859e-04
# Epoch 97/100
# 10/10 [==============================] - 0s 4ms/step - loss: 3.1175e-06 - val_loss: 1.6749e-04
# Epoch 98/100
# 10/10 [==============================] - 0s 4ms/step - loss: 3.3705e-06 - val_loss: 1.7146e-04
# Epoch 99/100
# 10/10 [==============================] - 0s 4ms/step - loss: 3.0053e-06 - val_loss: 1.6392e-04
# Epoch 100/100
# 10/10 [==============================] - 0s 4ms/step - loss: 2.9016e-06 - val_loss: 1.7347e-04
# LSTM running time: 6.97 seconds

# %% [markdown]
# ### Plotting predictions

# %%
# Make predictions
predicted = model.predict(X_test)

# Plot
plt.figure(figsize=(15,5))
plt.plot(y_test.values.flatten(), label='True Values')
plt.plot(predicted.flatten(), label='Predicted Values')
plt.title('LSTM Model Predictions')
plt.legend()
plt.show()

# reverse the scaling on predictions !!


# Evaluate
mse = mean_squared_error(y_test, predicted)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, predicted)
print(f'MSE: {mse}')
print(f'RMSE: {rmse}')
print(f'MAE: {mae}')
# Out:
# WARNING:tensorflow:5 out of the last 33 calls to <function Model.make_predict_function.<locals>.predict_function at 0x295744b80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 [==============================] - 0s 1ms/step
# MSE: 0.0007832416747011911
# RMSE: 0.0279864552007072
# MAE: 0.02638485455035521

# %% [markdown]
# ### Learning Curve

# %%
# Plot the training and validation loss
plt.figure(figsize=(14, 7))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Store results
add_model_results('LSTM 1', mse, mae, rmse)

# %%
# Use the last sequence of the training data for forecasting
last_sequence = X_train[-1].reshape(1, -1, 1)  # Shape: (1, timesteps, 1)

# Forecast for next 1 day, 1 week, and 1 month
forecast_steps = [1, 5, 20]
forecasts = []

for step in range(max(forecast_steps)):
    next_pred = model.predict(last_sequence)  # Shape: (1, 1)
    forecasts.append(next_pred[0][0])  # Append the scalar prediction
    next_pred_reshaped = np.reshape(next_pred, (1, 1, 1))  # Reshape to (1, 1, 1)
    last_sequence = np.append(last_sequence[:, 1:, :], next_pred_reshaped, axis=1)  # Update sequence

# Inverse transform the forecasts
forecasts_original = X.inverse_transform(np.array(forecasts).reshape(-1, 1))

# Print forecasts
print(f"1-Day Forecast: {forecasts_original[0][0]}")
print(f"1-Week Forecast: {forecasts_original[:5].flatten()}")
print(f"1-Month Forecast: {forecasts_original[:20].flatten()}")
# Out:
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[83], line 15
#      12     last_sequence = np.append(last_sequence[:, 1:, :], next_pred_reshaped, axis=1)  # Update sequence
#      14 # Inverse transform the forecasts
# ---> 15 forecasts_original = X.inverse_transform(np.array(forecasts).reshape(-1, 1))
#      17 # Print forecasts
#      18 print(f"1-Day Forecast: {forecasts_original[0][0]}")
#
# AttributeError: 'numpy.ndarray' object has no attribute 'inverse_transform'

# %%
# Convert the dictionary into a DataFrame for visualization
metrics_df = pd.DataFrame(model_results).T
metrics_df.reset_index(inplace=True)
metrics_df.rename(columns={'index': 'Model'}, inplace=True)

# Define metrics to plot
metrics = ['MSE', 'MAE', 'RMSE']

# Initialize the plot
plt.figure(figsize=(16, 8))

# Plot each metric
for i, metric in enumerate(metrics, 1):
    plt.subplot(1, len(metrics), i)
    sns.barplot(data=metrics_df, x='Model', y=metric, palette='husl')
    plt.title(f'{metric} Comparison')
    plt.xlabel('Model')
    plt.ylabel(metric)
    plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
metrics_df
# Out:
#                Model       MSE       MAE      RMSE
# 0  Linear Regression  0.003700  0.046900  0.061200
# 1             LSTM 1  0.000417  0.019428  0.020417

# %%
# Filter specific SARIMA models with normalized values
models_to_plot = ['AutoARIMA (Normalized)', 
                  'AutoARIMA (Normalized m=63)', 
                  'SARIMA (Cross-Validation)',
                 'SARIMA (AUTO ARIMA m=5)','LSTM 1']

filtered_df = metrics_df[metrics_df['Model'].isin(models_to_plot)]

# Metrics to plot
metrics_to_plot = ['MSE', 'MAE', 'RMSE']

# Plot each metric separately
fig, axes = plt.subplots(1, len(metrics_to_plot), figsize=(16, 6), sharey=False)

for i, metric in enumerate(metrics_to_plot):
    sns.barplot(
        data=filtered_df,
        x='Model',
        y=metric,
        ax=axes[i],
        palette='husl'
    )
    axes[i].set_title(f'{metric} Comparison')
    axes[i].set_xlabel('Model')
    axes[i].set_ylabel(metric)
    axes[i].tick_params(axis='x', rotation=45)  # Rotate labels

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# ## LSTM (2)
# ### Data prep for LSTM
#
# **1. Start TIme Series Data = ICIP prices (US$ per pd)**

# %%
# Extract the 'I-CIP' column as the target variable
data = df['I-CIP'].values.reshape(-1, 1)

# %% [markdown]
# **2. Scale data**
#
# LSTM models need normalisation as they are sensitive to scale of input data. These values will be scaled back to their original for plotting results.

# %%
# Normalize data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

# %%
print(scaled_data)
# Out:
# [[0.2092179 ]
#  [0.18530503]
#  [0.19966853]
#  [0.20637677]
#  [0.19919501]
#  [0.18861968]
#  [0.19193434]
#  [0.20132586]
#  [0.23573514]
#  [0.20314103]
#  [0.22034567]
#  [0.24938837]
#  [0.25001973]
#  [0.27227527]
#  [0.29879252]
#  [0.27558993]
#  [0.26020046]
#  [0.24670507]
#  [0.24804672]
#  [0.23628759]
#  [0.22957935]
#  [0.20732381]
#  [0.2134796 ]
#  [0.22760635]
#  [0.20258859]
#  [0.19035593]
#  [0.2049562 ]
#  [0.20266751]
#  [0.17346697]
#  [0.15918238]
#  [0.20337779]
#  [0.17812327]
#  [0.18593639]
#  [0.20061558]
#  [0.18246389]
#  [0.16825823]
#  [0.19872149]
#  [0.1879094 ]
#  [0.16336516]
#  [0.14497672]
#  [0.1499487 ]
#  [0.15294768]
#  [0.18056981]
#  [0.17480862]
#  [0.20874438]
#  [0.21908295]
#  [0.22074027]
#  [0.21632073]
#  [0.26280483]
#  [0.26051614]
#  [0.29863468]
#  [0.27124931]
#  [0.30905217]
#  [0.32594113]
#  [0.31386631]
#  [0.28071975]
#  [0.26619841]
#  [0.28861179]
#  [0.26122642]
#  [0.2688817 ]
#  [0.27803646]
#  [0.23684003]
#  [0.2522295 ]
#  [0.23660327]
#  [0.23123668]
#  [0.21971431]
#  [0.24236445]
#  [0.22800095]
#  [0.24457422]
#  [0.24528451]
#  [0.21126983]
#  [0.21632073]
#  [0.25341331]
#  [0.2437061 ]
#  [0.24812564]
#  [0.24646831]
#  [0.26201563]
#  [0.2603583 ]
#  [0.24378502]
#  [0.248757  ]
#  [0.21679425]
#  [0.20913898]
#  [0.21190119]
#  [0.18846184]
#  [0.19319706]
#  [0.21758346]
#  [0.23384105]
#  [0.21434772]
#  [0.21434772]
#  [0.22950043]
#  [0.28450793]
#  [0.26446216]
#  [0.21979323]
#  [0.20527188]
#  [0.21071739]
#  [0.23407782]
#  [0.22934259]
#  [0.23581406]
#  [0.21016494]
#  [0.18451582]
#  [0.17796543]
#  [0.14623944]
#  [0.15705154]
#  [0.16502249]
#  [0.12966617]
#  [0.12264225]
#  [0.09849262]
#  [0.10259648]
#  [0.09446768]
#  [0.08476048]
#  [0.09794018]
#  [0.11380317]
#  [0.10196512]
#  [0.09778234]
#  [0.09210007]
#  [0.0929682 ]
#  [0.10093915]
#  [0.07623708]
#  [0.0778944 ]
#  [0.08191934]
#  [0.08878542]
#  [0.11672323]
#  [0.12950833]
#  [0.13140241]
#  [0.12351038]
#  [0.11735459]
#  [0.0906795 ]
#  [0.12272117]
#  [0.1239839 ]
#  [0.13913661]
#  [0.12382606]
#  [0.09596717]
#  [0.11656539]
#  [0.1108042 ]
#  [0.09967643]
#  [0.09683529]
#  [0.07868361]
#  [0.04198564]
#  [0.03890774]
#  [0.02430747]
#  [0.02643832]
#  [0.02912162]
#  [0.02564912]
#  [0.0220977 ]
#  [0.04482677]
#  [0.04822035]
#  [0.04743114]
#  [0.04537921]
#  [0.04672086]
#  [0.06550391]
#  [0.05769079]
#  [0.05027228]
#  [0.04751006]
#  [0.05548102]
#  [0.05840107]
#  [0.04411649]
#  [0.04774682]
#  [0.06116329]
#  [0.03906558]
#  [0.05327125]
#  [0.06668771]
#  [0.09667745]
#  [0.09991319]
#  [0.11190908]
#  [0.09651961]
#  [0.07757872]
#  [0.05816431]
#  [0.03306763]
#  [0.03164707]
#  [0.02367611]
#  [0.01633652]
#  [0.01475811]
#  [0.02998974]
#  [0.02927946]
#  [0.01381106]
#  [0.00749744]
#  [0.00252545]
#  [0.        ]
#  [0.00449846]
#  [0.00536659]
#  [0.01617868]
#  [0.04451109]
#  [0.04166996]
#  [0.04987767]
#  [0.05871675]
#  [0.08554968]
#  [0.09525689]
#  [0.10314892]
#  [0.11127772]
#  [0.08160366]
#  [0.07236998]
#  [0.05374477]
#  [0.04372188]
#  [0.08231395]
#  [0.05784863]
#  [0.07134401]
#  [0.10093915]
#  [0.11727567]
#  [0.0992029 ]
#  [0.11648647]
#  [0.13503275]
#  [0.11111988]
#  [0.13503275]
#  [0.13148134]
#  [0.16091863]
#  [0.14363507]
#  [0.11364533]
#  [0.13416463]
#  [0.11853839]
#  [0.12453634]
#  [0.12256333]
#  [0.12422066]
#  [0.11727567]
#  [0.13747928]
#  [0.13542735]
#  [0.18940889]
#  [0.18759372]
#  [0.16076079]
#  [0.19019809]
#  [0.14150422]
#  [0.15791966]
#  [0.16162892]
#  [0.20953358]
#  [0.21655749]
#  [0.23897088]
#  [0.25286086]
#  [0.24978297]
#  [0.25365007]
#  [0.31607608]
#  [0.26280483]
#  [0.28482361]
#  [0.26327835]
#  [0.27348539]
#  [0.28369242]
#  [0.29389946]
#  [0.30668456]
#  [0.24417962]
#  [0.23242049]
#  [0.22066135]
#  [0.19801121]
#  [0.19998422]
#  [0.21718886]
#  [0.21979323]
#  [0.22752742]
#  [0.21411096]
#  [0.21766238]
#  [0.20479836]
#  [0.20164154]
#  [0.21971431]
#  [0.21442664]
#  [0.20819193]
#  [0.23912872]
#  [0.26209455]
#  [0.27148607]
#  [0.27243311]
#  [0.27764186]
#  [0.29516218]
#  [0.27969379]
#  [0.30739484]
#  [0.31213006]
#  [0.30976245]
#  [0.29752979]
#  [0.27574777]
#  [0.273538  ]
#  [0.28947991]
#  [0.28119328]
#  [0.32420488]
#  [0.32175835]
#  [0.30368558]
#  [0.26738221]
#  [0.28292952]
#  [0.29216321]
#  [0.29516218]
#  [0.28995344]
#  [0.30076553]
#  [0.26856602]
#  [0.25104569]
#  [0.24852024]
#  [0.27022334]
#  [0.26146318]
#  [0.2692763 ]
#  [0.27937811]
#  [0.29287349]
#  [0.28395549]
#  [0.31394523]
#  [0.35324757]
#  [0.31291926]
#  [0.30905217]
#  [0.31757557]
#  [0.29713519]
#  [0.30486939]
#  [0.30834188]
#  [0.30818404]
#  [0.31007813]
#  [0.30273854]
#  [0.31860153]
#  [0.3169442 ]
#  [0.33249152]
#  [0.34748639]
#  [0.37305659]
#  [0.35537842]
#  [0.35743035]
#  [0.37408255]
#  [0.42451267]
#  [0.47107568]
#  [0.46342041]
#  [0.4754163 ]
#  [0.46965512]
#  [0.48157209]
#  [0.49151606]
#  [0.53255465]
#  [0.57469813]
#  [0.60879173]
#  [0.6241812 ]
#  [0.70641623]
#  [0.64769947]
#  [0.65101413]
#  [0.62220819]
#  [0.59340226]
#  [0.6334938 ]
#  [0.65424986]
#  [0.61352695]
#  [0.62789046]
#  [0.56909478]
#  [0.56467524]
#  [0.46965512]
#  [0.43358851]
#  [0.40715019]
#  [0.39183963]
#  [0.39452293]
#  [0.41078052]
#  [0.41740983]
#  [0.38781469]
#  [0.41480546]
#  [0.40131008]
#  [0.39854787]
#  [0.45868519]
#  [0.45813274]
#  [0.5335017 ]
#  [0.57319864]
#  [0.54297214]
#  [0.56806882]
#  [0.55844053]
#  [0.64256965]
#  [0.6400442 ]
#  [0.66782417]
#  [0.58937732]
#  [0.62426012]
#  [0.66474627]
#  [0.67666325]
#  [0.68629153]
#  [0.63112619]
#  [0.60839713]
#  [0.59758504]
#  [0.62220819]
#  [0.63278352]
#  [0.61455292]
#  [0.63396733]
#  [0.62126115]
#  [0.62907426]
#  [0.66474627]
#  [0.62615421]
#  [0.70791571]
#  [0.650146  ]
#  [0.61755189]
#  [0.62907426]
#  [0.62173467]
#  [0.62173467]
#  [0.64888328]
#  [0.62757478]
#  [0.63964959]
#  [0.66900797]
#  [0.71864888]
#  [0.83410938]
#  [0.78075921]
#  [0.80096283]
#  [0.80790782]
#  [0.77199905]
#  [0.77768132]
#  [0.77136769]
#  [0.75171652]
#  [0.75337385]
#  [0.7745245 ]
#  [0.74437692]
#  [0.68652829]
#  [0.69473601]
#  [0.64691027]
#  [0.64035988]
#  [0.64209613]
#  [0.63073159]
#  [0.62007734]
#  [0.63838687]
#  [0.60445111]
#  [0.66411491]
#  [0.72109541]
#  [0.70444322]
#  [0.65732776]
#  [0.71438718]
#  [0.64777839]
#  [0.69150028]
#  [0.71975377]
#  [0.760161  ]
#  [0.76702707]
#  [0.80372504]
#  [0.80806566]
#  [0.7694736 ]
#  [0.77641859]
#  [0.78746745]
#  [0.83292558]
#  [0.85336595]
#  [0.80056823]
#  [0.79180807]
#  [0.75542578]
#  [0.75140084]
#  [0.78415279]
#  [0.81871991]
#  [0.7725515 ]
#  [0.80088391]
#  [0.83016337]
#  [0.84279062]
#  [0.86204719]
#  [0.94451898]
#  [0.93583774]
#  [0.97435088]
#  [0.97450872]
#  [0.9399416 ]
#  [0.86252072]
#  [0.95327914]
#  [0.97734985]
#  [0.97940178]
#  [1.        ]
#  [0.9705627 ]
#  [0.98161155]]

# %% [markdown]
# **3. Create Sliding Windows (Sequences)**
#
#
#
# ## window_size = 5
#
# To structure the data, inputs(X) and outputs(y) sequences need to be created
#
#
# X: Contains sequences of a fixed length (first 5, then maybe 10 timesteps?).
# y: The value immediately following each sequence.

# %%
def create_lstm_sequences(data, window_size):
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i:i + window_size, 0])  # Past `window_size` values
        y.append(data[i + window_size, 0])   # The value after the sequence
    return np.array(X), np.array(y)

# Define the window size (number of timesteps)
window_size = 5

# Generate sequences
X, y = create_lstm_sequences(scaled_data, window_size)

# %% [markdown]
# **4. Reshape Input for LSTM (3 dimensions)**
#
# The LSTM layer requires the input in the shape [samples, timesteps, features].
#
# samples: Number of sliding windows created.
# timesteps: Length of each sliding window.
# features: Number of features (1 for univariate time series).

# %%
# Reshape X for LSTM input
X = X.reshape((X.shape[0], X.shape[1], 1))

# %% [markdown]
# **5. Split the Data into Training (80%) and Testing Sets**
#
# ensuring that the sequence order is preserved.

# %%
# Define the training size (80% of the data for training)
train_size = int(len(X) * 0.8)

# Split into training and testing sets
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Check the shapes
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
# Out:
# X_train shape: (342, 5, 1), y_train shape: (342,)
# X_test shape: (86, 5, 1), y_test shape: (86,)

# %%
# Build and train the model
model_minmax = Sequential([
    LSTM(50, return_sequences=False, input_shape=(10, 1)),
    Dense(1)
])
model_minmax.compile(optimizer='adam', loss='mse')

history_minmax = model_minmax.fit(
    X_train_minmax, y_train_minmax,
    epochs=50,
    batch_size=32,
    validation_data=(X_test_minmax, y_test_minmax),
    verbose=1
)

# Evaluate and inverse transform predictions
predictions_minmax = model_minmax.predict(X_test_minmax)
predictions_minmax_original = min_max_scaler.inverse_transform(predictions_minmax)
y_test_minmax_original = min_max_scaler.inverse_transform(y_test_minmax.reshape(-1, 1))
# Out:
# Epoch 1/50
# 11/11 [==============================] - 1s 28ms/step - loss: 0.0502 - val_loss: 0.1319
# Epoch 2/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0097 - val_loss: 0.0079
# Epoch 3/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0066 - val_loss: 0.0395
# Epoch 4/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0048 - val_loss: 0.0137
# Epoch 5/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0033 - val_loss: 0.0036
# Epoch 6/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0027 - val_loss: 0.0036
# Epoch 7/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0026 - val_loss: 0.0050
# Epoch 8/50
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 0.0043
# Epoch 9/50
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0025 - val_loss: 0.0056
# Epoch 10/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0025 - val_loss: 0.0039
# Epoch 11/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0023 - val_loss: 0.0048
# Epoch 12/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0023 - val_loss: 0.0034
# Epoch 13/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0022 - val_loss: 0.0046
# Epoch 14/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0024 - val_loss: 0.0034
# Epoch 15/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0022 - val_loss: 0.0033
# Epoch 16/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0021 - val_loss: 0.0035
# Epoch 17/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0020 - val_loss: 0.0032
# Epoch 18/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0020 - val_loss: 0.0030
# Epoch 19/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0020 - val_loss: 0.0035
# Epoch 20/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0019 - val_loss: 0.0028
# Epoch 21/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 22/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 0.0028
# Epoch 23/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 0.0029
# Epoch 24/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 25/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 26/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 27/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 0.0029
# Epoch 28/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 0.0025
# Epoch 29/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0015 - val_loss: 0.0025
# Epoch 30/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0023
# Epoch 31/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0027
# Epoch 32/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0026
# Epoch 33/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0034
# Epoch 34/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0028
# Epoch 35/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.0046
# Epoch 36/50
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 0.0045
# Epoch 37/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.0033
# Epoch 38/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.0044
# Epoch 39/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0058
# Epoch 40/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0121
# Epoch 41/50
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 0.0092
# Epoch 42/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.0029
# Epoch 43/50
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 0.0029
# Epoch 44/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0089
# Epoch 45/50
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 0.0045
# Epoch 46/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0049
# Epoch 47/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0010 - val_loss: 0.0054
# Epoch 48/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0010 - val_loss: 0.0066
# Epoch 49/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0033
# Epoch 50/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0010 - val_loss: 0.0134
# 3/3 [==============================] - 0s 2ms/step

# %%
# Evaluate the model
loss, mae = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss (MSE): {loss:.4f}, Test MAE: {mae:.4f}")

# Make predictions
predictions = model.predict(X_test)

# Inverse transform the predictions and actual values
scaled_predictions = predictions.flatten()
original_predictions = scaler.inverse_transform(scaled_predictions.reshape(-1, 1))
original_y_test = scaler.inverse_transform(y_test.reshape(-1, 1))

# Plot actual vs predicted values
plt.figure(figsize=(10, 6))
plt.plot(original_y_test, label='Actual Values', color='blue')
plt.plot(original_predictions, label='Predicted Values', color='red', linestyle='--')
plt.legend()
plt.title("LSTM: Actual vs Predicted")
plt.show()

# Calculate error metrics
mse = mean_squared_error(original_y_test, original_predictions)
mae = mean_absolute_error(original_y_test, original_predictions)
rmse = np.sqrt(mse)
print(f"Performance Metrics:\nMSE: {mse:.4f}, MAE: {mae:.4f}, RMSE: {rmse:.4f}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 2
#       1 # Evaluate the model
# ----> 2 loss, mae = model.evaluate(X_test, y_test, verbose=0)
#       3 print(f"Test Loss (MSE): {loss:.4f}, Test MAE: {mae:.4f}")
#       5 # Make predictions
#
# File ~/anaconda3/lib/python3.10/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File /var/folders/fx/bjw0pmnj07j5b5pyyx7xdxv40000gn/T/__autograph_generated_filej4ulagy0.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__test_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# ValueError: in user code:
#
#     File "/Users/clarissacardoso/anaconda3/lib/python3.10/site-packages/keras/engine/training.py", line 1727, in test_function  *
#         return step_function(self, iterator)
#     File "/Users/clarissacardoso/anaconda3/lib/python3.10/site-packages/keras/engine/training.py", line 1713, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/clarissacardoso/anaconda3/lib/python3.10/site-packages/keras/engine/training.py", line 1701, in run_step  **
#         outputs = model.test_step(data)
#     File "/Users/clarissacardoso/anaconda3/lib/python3.10/site-packages/keras/engine/training.py", line 1665, in test_step
#         y_pred = self(x, training=False)
#     File "/Users/clarissacardoso/anaconda3/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/clarissacardoso/anaconda3/lib/python3.10/site-packages/keras/engine/input_spec.py", line 295, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "sequential" is incompatible with the layer: expected shape=(None, 1, 1), found shape=(None, 5, 1)

# %%
# Make predictions
predicted = model.predict(X_test)

# Plot
plt.figure(figsize=(15,5))
plt.plot(y_test.values.flatten(), label='True Values')
plt.plot(predicted.flatten(), label='Predicted Values')
plt.title('LSTM Model Predictions')
plt.legend()
plt.show()

# reverse the scaling on predictions !!


# Evaluate
mse = mean_squared_error(y_test, predicted)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, predicted)
print(f'MSE: {mse}')
print(f'RMSE: {rmse}')
print(f'MAE: {mae}')

# %% [markdown]
# ## 20 epochs

# %%
# Build the LSTM model
model = tf.keras.Sequential([
    tf.keras.layers.LSTM(50, return_sequences=False, input_shape=(X_train.shape[1], 1)),
    tf.keras.layers.Dense(1)
])

# Compile the model
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# Train the model
history = model.fit(
    X_train, y_train,
    epochs=20,
    batch_size=32,
    validation_data=(X_test, y_test),
    verbose=1
)

# Evaluate the model
loss, mae = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss (MSE): {loss:.4f}, Test MAE: {mae:.4f}")

# Make predictions
predictions = model.predict(X_test)

# Inverse transform the predictions and actual values
scaled_predictions = predictions.flatten()
original_predictions = scaler.inverse_transform(scaled_predictions.reshape(-1, 1))
original_y_test = scaler.inverse_transform(y_test.reshape(-1, 1))

# Plot actual vs predicted values
plt.figure(figsize=(10, 6))
plt.plot(original_y_test, label='Actual Values', color='blue')
plt.plot(original_predictions, label='Predicted Values', color='red', linestyle='--')
plt.legend()
plt.title("LSTM: Actual vs Predicted")
plt.show()

# Calculate error metrics
mse = mean_squared_error(original_y_test, original_predictions)
mae = mean_absolute_error(original_y_test, original_predictions)
rmse = np.sqrt(mse)
print(f"Performance Metrics:\nMSE: {mse:.4f}, MAE: {mae:.4f}, RMSE: {rmse:.4f}")

# %%
# Store results
add_model_results('LSTM 2 (20epochs)', mse, mae, rmse, mape)

# %%
# Plot the training and validation loss
plt.figure(figsize=(14, 7))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ## LSTM (3)
# ### Same code but now with **100** epochs

# %%
# Build the LSTM model
model = tf.keras.Sequential([
    tf.keras.layers.LSTM(50, return_sequences=False, input_shape=(X_train.shape[1], 1)),
    tf.keras.layers.Dense(1)
])

# Compile the model
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# Train the model
history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=32,
    validation_data=(X_test, y_test),
    verbose=1
)

# Evaluate the model
loss, mae = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss (MSE): {loss:.4f}, Test MAE: {mae:.4f}")

# Make predictions
predictions = model.predict(X_test)

# Inverse transform the predictions and actual values
scaled_predictions = predictions.flatten()
original_predictions = scaler.inverse_transform(scaled_predictions.reshape(-1, 1))
original_y_test = scaler.inverse_transform(y_test.reshape(-1, 1))

# Plot actual vs predicted values
plt.figure(figsize=(10, 6))
plt.plot(original_y_test, label='Actual Values', color='blue')
plt.plot(original_predictions, label='Predicted Values', color='red', linestyle='--')
plt.legend()
plt.title("LSTM: Actual vs Predicted")
plt.show()

# Calculate error metrics
mse = mean_squared_error(original_y_test, original_predictions)
mae = mean_absolute_error(original_y_test, original_predictions)
rmse = np.sqrt(mse)
print(f"Performance Metrics:\nMSE: {mse:.4f}, MAE: {mae:.4f}, RMSE: {rmse:.4f}")

# %%
# Plot the training and validation loss
plt.figure(figsize=(14, 7))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Store results
add_model_results('LSTM 3 (100epochs)', mse, mae, rmse, mape)

# %% [markdown]
# ## LSTM (4)
# ## 200 epochs?

# %%
# Build the LSTM model
model = tf.keras.Sequential([
    tf.keras.layers.LSTM(50, return_sequences=False, input_shape=(X_train.shape[1], 1)),
    tf.keras.layers.Dense(1)
])

# Compile the model
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# Train the model
history = model.fit(
    X_train, y_train,
    epochs=200,
    batch_size=32,
    validation_data=(X_test, y_test),
    verbose=1
)

# Evaluate the model
loss, mae = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss (MSE): {loss:.4f}, Test MAE: {mae:.4f}")

# Make predictions
predictions = model.predict(X_test)

# Inverse transform the predictions and actual values
scaled_predictions = predictions.flatten()
original_predictions = scaler.inverse_transform(scaled_predictions.reshape(-1, 1))
original_y_test = scaler.inverse_transform(y_test.reshape(-1, 1))

# Plot actual vs predicted values
plt.figure(figsize=(10, 6))
plt.plot(original_y_test, label='Actual Values', color='blue')
plt.plot(original_predictions, label='Predicted Values', color='red', linestyle='--')
plt.legend()
plt.title("LSTM: Actual vs Predicted")
plt.show()

# Calculate error metrics
mse = mean_squared_error(original_y_test, original_predictions)
mae = mean_absolute_error(original_y_test, original_predictions)
rmse = np.sqrt(mse)
print(f"Performance Metrics:\nMSE: {mse:.4f}, MAE: {mae:.4f}, RMSE: {rmse:.4f}")

# %%
# Plot the training and validation loss
plt.figure(figsize=(14, 7))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Store results
add_model_results('LSTM 4 (200epochs)', mse, mae, rmse, mape)

# %% [markdown]
# ## LSTM (5)
# ## Testing with window of 10 timesteps to capture long-term dependencies betweeen data
#
# with early stopping to stop training once the loss reaches its minimum

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Window size
window_size = 10  # 

# Recreate sliding windows
X, y = create_lstm_sequences(scaled_data, window_size)

# Reshape for LSTM
X = X.reshape((X.shape[0], X.shape[1], 1))

# Split into train and test
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Define the model
model = tf.keras.Sequential([
    tf.keras.layers.LSTM(64, return_sequences=True, input_shape=(window_size, 1)),
    tf.keras.layers.LSTM(50, return_sequences=False),
    tf.keras.layers.Dense(1)
])

# Compile the model
model.compile(optimizer='adam', loss='mse')

# Add early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = model.fit(
    X_train, y_train,
    epochs=100, #100 epochs results were MSE: 38/ with 
    batch_size=32,
    validation_data=(X_test, y_test),
    callbacks=[early_stopping],
    verbose=1
)

# Evaluate the model
loss = model.evaluate(X_test, y_test, verbose=0)
predictions = model.predict(X_test)

# Inverse transform predictions
scaled_predictions = predictions.flatten()
original_predictions = scaler.inverse_transform(scaled_predictions.reshape(-1, 1))
original_y_test = scaler.inverse_transform(y_test.reshape(-1, 1))

# Plot actual vs predicted values
plt.figure(figsize=(12, 6))
plt.plot(original_y_test, label='True Values', color='blue')
plt.plot(original_predictions, label='Predicted Values', color='orange')
plt.legend()
plt.title("LSTM Model Predictions")
plt.show()

# Calculate error metrics
mse = mean_squared_error(original_y_test, original_predictions)
mae = mean_absolute_error(original_y_test, original_predictions)
rmse = np.sqrt(mse)
print(f"Performance Metrics:\nMSE: {mse:.4f}, MAE: {mae:.4f}, RMSE: {rmse:.4f}")
# Out:
# Epoch 1/100
# 11/11 [==============================] - 2s 48ms/step - loss: 0.0316 - val_loss: 0.0045
# Epoch 2/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0089 - val_loss: 0.0604
# Epoch 3/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0052 - val_loss: 0.0042
# Epoch 4/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0033 - val_loss: 0.0052
# Epoch 5/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0029 - val_loss: 0.0045
# Epoch 6/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0027 - val_loss: 0.0042
# Epoch 7/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0027 - val_loss: 0.0056
# Epoch 8/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0025 - val_loss: 0.0057
# Epoch 9/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0026 - val_loss: 0.0041
# Epoch 10/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0025 - val_loss: 0.0036
# Epoch 11/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0024 - val_loss: 0.0038
# Epoch 12/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0024 - val_loss: 0.0037
# Epoch 13/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0023 - val_loss: 0.0034
# Epoch 14/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0023 - val_loss: 0.0047
# Epoch 15/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0023 - val_loss: 0.0032
# Epoch 16/100
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0021 - val_loss: 0.0032
# Epoch 17/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0021 - val_loss: 0.0032
# Epoch 18/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0021 - val_loss: 0.0043
# Epoch 19/100
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0020 - val_loss: 0.0029
# Epoch 20/100
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0020 - val_loss: 0.0029
# Epoch 21/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0018 - val_loss: 0.0027
# Epoch 22/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 0.0033
# Epoch 23/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0016 - val_loss: 0.0055
# Epoch 24/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0015 - val_loss: 0.0063
# Epoch 25/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0014 - val_loss: 0.0081
# Epoch 26/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0013 - val_loss: 0.0135
# Epoch 27/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0012 - val_loss: 0.0152
# Epoch 28/100
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0012 - val_loss: 0.0124
# Epoch 29/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0012 - val_loss: 0.0040
# Epoch 30/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0014 - val_loss: 0.0192
# Epoch 31/100
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0016 - val_loss: 0.0043
# 3/3 [==============================] - 0s 3ms/step
# Performance Metrics:
# MSE: 43.1419, MAE: 5.4456, RMSE: 6.5682

# %%
# Plot the training and validation loss
plt.figure(figsize=(14, 7))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Store results
add_model_results('LSTM (5)', mse, mae, rmse)

# %%
from tensorflow.keras.layers import Dropout, Bidirectional

# Define a more complex LSTM model
complex_model = tf.keras.Sequential([
    Bidirectional(LSTM(64, return_sequences=True, input_shape=(window_size, 1))),
    Dropout(0.2),  # Add dropout for regularization
    LSTM(128, return_sequences=True),
    Dropout(0.2),
    LSTM(64, return_sequences=False),
    Dense(50, activation='relu'),  # Add a Dense layer with ReLU activation
    Dense(1)  # Output layer
])

# Compile the model
complex_model.compile(optimizer='adam', loss='mse')

# Train the model
history = complex_model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=32,
    validation_data=(X_test, y_test),
    verbose=1,
    callbacks=[early_stopping]
)

# Evaluate the model
complex_loss = complex_model.evaluate(X_test, y_test, verbose=0)
complex_predictions = complex_model.predict(X_test)

# Inverse transform predictions
complex_scaled_predictions = complex_predictions.flatten()
complex_original_predictions = scaler.inverse_transform(complex_scaled_predictions.reshape(-1, 1))
complex_original_y_test = scaler.inverse_transform(y_test.reshape(-1, 1))

# Plot results
plt.figure(figsize=(12, 6))
plt.plot(complex_original_y_test, label='True Values', color='blue')
plt.plot(complex_original_predictions, label='Predicted Values', color='orange')
plt.legend()
plt.title("Complex LSTM Model Predictions")
plt.show()

# Calculate error metrics
complex_mse = mean_squared_error(complex_original_y_test, complex_original_predictions)
complex_mae = mean_absolute_error(complex_original_y_test, complex_original_predictions)
complex_rmse = np.sqrt(complex_mse)
print(f"Complex LSTM Model Metrics:\nMSE: {complex_mse:.4f}, MAE: {complex_mae:.4f}, RMSE: {complex_rmse:.4f}")
# Out:
# Epoch 1/100
# 11/11 [==============================] - 5s 92ms/step - loss: 0.0209 - val_loss: 0.0961
# Epoch 2/100
# 11/11 [==============================] - 0s 22ms/step - loss: 0.0065 - val_loss: 0.0039
# Epoch 3/100
# 11/11 [==============================] - 0s 20ms/step - loss: 0.0031 - val_loss: 0.0052
# Epoch 4/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0031 - val_loss: 0.0065
# Epoch 5/100
# 11/11 [==============================] - 0s 22ms/step - loss: 0.0029 - val_loss: 0.0056
# Epoch 6/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0023 - val_loss: 0.0092
# Epoch 7/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0028 - val_loss: 0.0048
# Epoch 8/100
# 11/11 [==============================] - 0s 20ms/step - loss: 0.0024 - val_loss: 0.0039
# Epoch 9/100
# 11/11 [==============================] - 0s 21ms/step - loss: 0.0024 - val_loss: 0.0049
# Epoch 10/100
# 11/11 [==============================] - 0s 20ms/step - loss: 0.0021 - val_loss: 0.0036
# Epoch 11/100
# 11/11 [==============================] - 0s 20ms/step - loss: 0.0019 - val_loss: 0.0041
# Epoch 12/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0020 - val_loss: 0.0042
# Epoch 13/100
# 11/11 [==============================] - 0s 22ms/step - loss: 0.0018 - val_loss: 0.0066
# Epoch 14/100
# 11/11 [==============================] - 0s 29ms/step - loss: 0.0020 - val_loss: 0.0113
# Epoch 15/100
# 11/11 [==============================] - 0s 29ms/step - loss: 0.0020 - val_loss: 0.0053
# Epoch 16/100
# 11/11 [==============================] - 0s 30ms/step - loss: 0.0014 - val_loss: 0.0036
# Epoch 17/100
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0013 - val_loss: 0.0077
# Epoch 18/100
# 11/11 [==============================] - 0s 22ms/step - loss: 0.0015 - val_loss: 0.0045
# Epoch 19/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0012 - val_loss: 0.0031
# Epoch 20/100
# 11/11 [==============================] - 0s 20ms/step - loss: 0.0013 - val_loss: 0.0337
# Epoch 21/100
# 11/11 [==============================] - 0s 20ms/step - loss: 0.0021 - val_loss: 0.0029
# Epoch 22/100
# 11/11 [==============================] - 0s 21ms/step - loss: 0.0016 - val_loss: 0.0112
# Epoch 23/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0014 - val_loss: 0.0031
# Epoch 24/100
# 11/11 [==============================] - 0s 20ms/step - loss: 0.0013 - val_loss: 0.0043
# Epoch 25/100
# 11/11 [==============================] - 0s 20ms/step - loss: 0.0016 - val_loss: 0.0061
# Epoch 26/100
# 11/11 [==============================] - 0s 20ms/step - loss: 0.0012 - val_loss: 0.0197
# Epoch 27/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0015 - val_loss: 0.0396
# Epoch 28/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0017 - val_loss: 0.0131
# Epoch 29/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0014 - val_loss: 0.0113
# Epoch 30/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0012 - val_loss: 0.0053
# Epoch 31/100
# 11/11 [==============================] - 0s 20ms/step - loss: 0.0012 - val_loss: 0.0144
# 3/3 [==============================] - 1s 12ms/step
# Complex LSTM Model Metrics:
# MSE: 46.1707, MAE: 5.7889, RMSE: 6.7949

# %%
# Plot the training and validation loss
plt.figure(figsize=(14, 7))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Store results
add_model_results('Complex LSTM (6)', mse, mae, rmse)

# %% [markdown]
# ### Compare different scalin techniques for LSTM models
#
# # Min-Max Scaling vs Standard Scaling
#
# ### LSTM (7)
#
# Min Max with window of 10

# %%
# Function to create sequences
def create_sequences(data, window_size):
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i:i + window_size])
        y.append(data[i + window_size])
    return np.array(X), np.array(y)

# %%
# Min-Max Scaling
min_max_scaler = MinMaxScaler()
data_minmax = min_max_scaler.fit_transform(df[['I-CIP']].values)

# Create sequences
X_minmax, y_minmax = create_sequences(data_minmax, window_size=10)

# Reshape for LSTM (samples, timesteps, features)
X_minmax = X_minmax.reshape((X_minmax.shape[0], X_minmax.shape[1], 1))

# Split into training and testing sets
split_index = int(len(X_minmax) * 0.8)
X_train_minmax, X_test_minmax = X_minmax[:split_index], X_minmax[split_index:]
y_train_minmax, y_test_minmax = y_minmax[:split_index], y_minmax[split_index:]

# Build and train the model
model_minmax = Sequential([
    LSTM(50, return_sequences=False, input_shape=(10, 1)),
    Dense(1)
])
model_minmax.compile(optimizer='adam', loss='mse')

history_minmax = model_minmax.fit(
    X_train_minmax, y_train_minmax,
    epochs=50,
    batch_size=32,
    validation_data=(X_test_minmax, y_test_minmax),
    verbose=1
)

# Evaluate and inverse transform predictions
predictions_minmax = model_minmax.predict(X_test_minmax)
predictions_minmax_original = min_max_scaler.inverse_transform(predictions_minmax)
y_test_minmax_original = min_max_scaler.inverse_transform(y_test_minmax.reshape(-1, 1))
# Out:
# Epoch 1/50
# 11/11 [==============================] - 1s 27ms/step - loss: 0.0417 - val_loss: 0.0829
# Epoch 2/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0096 - val_loss: 0.0068
# Epoch 3/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0057 - val_loss: 0.0415
# Epoch 4/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0046 - val_loss: 0.0109
# Epoch 5/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0033 - val_loss: 0.0038
# Epoch 6/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0027 - val_loss: 0.0046
# Epoch 7/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0025 - val_loss: 0.0047
# Epoch 8/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0027 - val_loss: 0.0043
# Epoch 9/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0027 - val_loss: 0.0037
# Epoch 10/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0025 - val_loss: 0.0043
# Epoch 11/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0024 - val_loss: 0.0036
# Epoch 12/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0023 - val_loss: 0.0036
# Epoch 13/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0023 - val_loss: 0.0035
# Epoch 14/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0022 - val_loss: 0.0035
# Epoch 15/50
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0022 - val_loss: 0.0033
# Epoch 16/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0021 - val_loss: 0.0036
# Epoch 17/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0021 - val_loss: 0.0032
# Epoch 18/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0020 - val_loss: 0.0032
# Epoch 19/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0021 - val_loss: 0.0031
# Epoch 20/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0020 - val_loss: 0.0032
# Epoch 21/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0020 - val_loss: 0.0030
# Epoch 22/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 23/50
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 24/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 0.0029
# Epoch 25/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 0.0027
# Epoch 26/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 0.0027
# Epoch 27/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 0.0026
# Epoch 28/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 0.0026
# Epoch 29/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 0.0026
# Epoch 30/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 0.0026
# Epoch 31/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0015 - val_loss: 0.0024
# Epoch 32/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0015 - val_loss: 0.0035
# Epoch 33/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 34/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0031
# Epoch 35/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0023
# Epoch 36/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0046
# Epoch 37/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0022
# Epoch 38/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0030
# Epoch 39/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0062
# Epoch 40/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.0022
# Epoch 41/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0049
# Epoch 42/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.0059
# Epoch 43/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0026
# Epoch 44/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0058
# Epoch 45/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0042
# Epoch 46/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0061
# Epoch 47/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0032
# Epoch 48/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0010 - val_loss: 0.0070
# Epoch 49/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0084
# Epoch 50/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0034
# 3/3 [==============================] - 0s 2ms/step

# %%
# Metrics for Min-Max Scaling
mse_minmax = mean_squared_error(y_test_minmax_original, predictions_minmax_original)
mae_minmax = mean_absolute_error(y_test_minmax_original, predictions_minmax_original)
rmse_minmax = np.sqrt(mse_minmax)

print("Min-Max Scaling:")
print(f"MSE: {mse_minmax}, MAE: {mae_minmax}, RMSE: {rmse_minmax}")


# Store results
add_model_results('LSTM (7) min-max', mse, mae, rmse)
# Out:
# Min-Max Scaling:
# MSE: 53.897839511605255, MAE: 5.837467572380513, RMSE: 7.341514796798087

# %%
# Min-Max Scaling Plot
plt.figure(figsize=(12, 6))
plt.plot(y_test_minmax_original, label='True Values (Min-Max)', color='blue')
plt.plot(predictions_minmax_original, label='Predicted Values (Min-Max)', color='orange')
plt.legend()
plt.title("Min-Max Scaling: Actual vs Predicted")
plt.show()

# %% [markdown]
# ### LSTM (8)
# ### Standard Scaler uses standard deviation 1 and median 0 for scaling.

# %%
# Standard Scaling
standard_scaler = StandardScaler()
data_standard = standard_scaler.fit_transform(df[['I-CIP']].values)

# Create sequences
X_standard, y_standard = create_sequences(data_standard, window_size=10)

# Reshape for LSTM (samples, timesteps, features)
X_standard = X_standard.reshape((X_standard.shape[0], X_standard.shape[1], 1))

# Split into training and testing sets
split_index = int(len(X_standard) * 0.8)
X_train_standard, X_test_standard = X_standard[:split_index], X_standard[split_index:]
y_train_standard, y_test_standard = y_standard[:split_index], y_standard[split_index:]

# Build and train the model
model_standard = Sequential([
    LSTM(50, return_sequences=False, input_shape=(10, 1)),
    Dense(1)
])
model_standard.compile(optimizer='adam', loss='mse')

history_standard = model_standard.fit(
    X_train_standard, y_train_standard,
    epochs=50,
    batch_size=32,
    validation_data=(X_test_standard, y_test_standard),
    verbose=1
)

# Evaluate and inverse transform predictions
predictions_standard = model_standard.predict(X_test_standard)
predictions_standard_original = standard_scaler.inverse_transform(predictions_standard)
y_test_standard_original = standard_scaler.inverse_transform(y_test_standard.reshape(-1, 1))
# Out:
# Epoch 1/50
# 11/11 [==============================] - 1s 27ms/step - loss: 0.3029 - val_loss: 1.6141
# Epoch 2/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0926 - val_loss: 0.9694
# Epoch 3/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0659 - val_loss: 0.6841
# Epoch 4/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0455 - val_loss: 0.4035
# Epoch 5/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0348 - val_loss: 0.2112
# Epoch 6/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0318 - val_loss: 0.1733
# Epoch 7/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0310 - val_loss: 0.1749
# Epoch 8/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0301 - val_loss: 0.1810
# Epoch 9/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0293 - val_loss: 0.1816
# Epoch 10/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0286 - val_loss: 0.1790
# Epoch 11/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0282 - val_loss: 0.1894
# Epoch 12/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0276 - val_loss: 0.1862
# Epoch 13/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0268 - val_loss: 0.1808
# Epoch 14/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0256 - val_loss: 0.1730
# Epoch 15/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0246 - val_loss: 0.1528
# Epoch 16/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0240 - val_loss: 0.1498
# Epoch 17/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0230 - val_loss: 0.1985
# Epoch 18/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0220 - val_loss: 0.1722
# Epoch 19/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0210 - val_loss: 0.1562
# Epoch 20/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0199 - val_loss: 0.1561
# Epoch 21/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0190 - val_loss: 0.1945
# Epoch 22/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0184 - val_loss: 0.1838
# Epoch 23/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0174 - val_loss: 0.1817
# Epoch 24/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0166 - val_loss: 0.1742
# Epoch 25/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0160 - val_loss: 0.2310
# Epoch 26/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0158 - val_loss: 0.1421
# Epoch 27/50
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0155 - val_loss: 0.2439
# Epoch 28/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0162 - val_loss: 0.2335
# Epoch 29/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0163 - val_loss: 0.1948
# Epoch 30/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0162 - val_loss: 0.2251
# Epoch 31/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0153 - val_loss: 0.1923
# Epoch 32/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0149 - val_loss: 0.2689
# Epoch 33/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0149 - val_loss: 0.1568
# Epoch 34/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0144 - val_loss: 0.2400
# Epoch 35/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0144 - val_loss: 0.2492
# Epoch 36/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0138 - val_loss: 0.1957
# Epoch 37/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0136 - val_loss: 0.2657
# Epoch 38/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0140 - val_loss: 0.2510
# Epoch 39/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0134 - val_loss: 0.1920
# Epoch 40/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0134 - val_loss: 0.2210
# Epoch 41/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0134 - val_loss: 0.2821
# Epoch 42/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0130 - val_loss: 0.2263
# Epoch 43/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0132 - val_loss: 0.2526
# Epoch 44/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0128 - val_loss: 0.2389
# Epoch 45/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0128 - val_loss: 0.2674
# Epoch 46/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0126 - val_loss: 0.1943
# Epoch 47/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0124 - val_loss: 0.3225
# Epoch 48/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0124 - val_loss: 0.2626
# Epoch 49/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0122 - val_loss: 0.2080
# Epoch 50/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0121 - val_loss: 0.2928
# 3/3 [==============================] - 0s 2ms/step

# %%
# Metrics for Standard Scaling
mse_standard = mean_squared_error(y_test_standard_original, predictions_standard_original)
mae_standard = mean_absolute_error(y_test_standard_original, predictions_standard_original)
rmse_standard = np.sqrt(mse_standard)


print("\nStandard Scaling:")
print(f"MSE: {mse_standard}, MAE: {mae_standard}, RMSE: {rmse_standard}")

# Store results
add_model_results('LSTM (8) std scaler', mse, mae, rmse)
# Out:
# Standard Scaling:
# MSE: 293.62809077520683, MAE: 14.932792437385112, RMSE: 17.135579674326948

# %%
# Standard Scaling Plot
plt.figure(figsize=(12, 6))
plt.plot(y_test_standard_original, label='True Values (Standard)', color='blue')
plt.plot(predictions_standard_original, label='Predicted Values (Standard)', color='orange')
plt.legend()
plt.title("Standard Scaling: Actual vs Predicted")
plt.show()

# %% [markdown]
# ## Improving LSTM (7)
#
# Using  ***keras tuner***to improve MIN-MAX model
#
# also applying ***Cross Validation** using timeseries splits to respect the temporal order from the data

# %%
# Define the TimeSeriesSplit object
tscv = TimeSeriesSplit(n_splits=5)  # Define the number of splits

# %%
import keras_tuner as kt

# Define the model-building function for Keras Tuner
def build_model(hp):
    model = Sequential()
    model.add(LSTM(
        units=hp.Int('units', min_value=32, max_value=128, step=32),
        return_sequences=True,
        input_shape=(X_train_minmax.shape[1], X_train_minmax.shape[2])
    ))
    model.add(Dropout(hp.Float('dropout', min_value=0.1, max_value=0.5, step=0.1)))
    model.add(LSTM(
        units=hp.Int('units_2', min_value=32, max_value=128, step=32),
        return_sequences=False
    ))
    model.add(Dense(1))  # Single output
    model.compile(
        optimizer=tf.keras.optimizers.Adam(
            learning_rate=hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])
        ),
        loss='mse'
    )
    return model

# TimeSeriesSplit for cross-validation
tscv = TimeSeriesSplit(n_splits=5)

# Define the cross-validation function
def cross_validate_tuner(model_builder, X, y, tscv):
    val_losses = []
    for train_index, val_index in tscv.split(X):
        X_train_fold, X_val_fold = X[train_index], X[val_index]
        y_train_fold, y_val_fold = y[train_index], y[val_index]
        
        # Build the model for each fold
        model = model_builder()
        
        # Train the model
        model.fit(X_train_fold, y_train_fold, validation_data=(X_val_fold, y_val_fold),
                  epochs=50, batch_size=32, verbose=0)
        
        # Evaluate on the validation set
        val_loss = model.evaluate(X_val_fold, y_val_fold, verbose=0)
        val_losses.append(val_loss)
    
    return np.mean(val_losses)

# Custom objective for Keras Tuner with TimeSeriesSplit
class TimeSeriesObjective(kt.Objective):
    def __init__(self, name, direction):
        super().__init__(name=name, direction=direction)
    
    def compute(self, trial):
        model_builder = lambda: tuner.hypermodel.build(trial.hyperparameters)
        return cross_validate_tuner(model_builder, X_train_minmax, y_train_minmax, tscv)

# Initialize the Keras Tuner with cross-validation
tuner = kt.Hyperband(
    build_model,  # Pass the build_model function
    objective=kt.Objective('val_loss', direction='min'),
    max_epochs=50,
    directory='tuner_results',
    project_name='lstm_time_series_cv'
)

# Run the search
tuner.search(X_train_minmax, y_train_minmax, validation_data=(X_test_minmax, y_test_minmax), epochs=50)

# Get the best hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print(f"Best Hyperparameters: {best_hps.values}")
# Out:
# Reloading Tuner from tuner_results/lstm_time_series_cv/tuner0.json
# Best Hyperparameters: {'units': 128, 'dropout': 0.2, 'units_2': 96, 'learning_rate': 0.01, 'tuner/epochs': 50, 'tuner/initial_epoch': 17, 'tuner/bracket': 1, 'tuner/round': 1, 'tuner/trial_id': '0076'}

# %% [markdown]
# #### Trainning best parameters

# %%
# Get the best hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

# Build the model with the best hyperparameters
best_model = tuner.hypermodel.build(best_hps)

# Train the model on the full training data
history = best_model.fit(
    X_train_minmax, y_train_minmax,
    validation_data=(X_test_minmax, y_test_minmax),
    epochs=100,
    batch_size=32,
    verbose=1,
    callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)]
)

# Plot training and validation loss
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')
plt.title('Training and Validation Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss (MSE)')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 11/11 [==============================] - 2s 52ms/step - loss: 0.0571 - val_loss: 0.1956
# Epoch 2/100
# 11/11 [==============================] - 0s 15ms/step - loss: 0.0134 - val_loss: 0.0263
# Epoch 3/100
# 11/11 [==============================] - 0s 15ms/step - loss: 0.0042 - val_loss: 0.0191
# Epoch 4/100
# 11/11 [==============================] - 0s 15ms/step - loss: 0.0029 - val_loss: 0.0058
# Epoch 5/100
# 11/11 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0154
# Epoch 6/100
# 11/11 [==============================] - 0s 15ms/step - loss: 0.0026 - val_loss: 0.0113
# Epoch 7/100
# 11/11 [==============================] - 0s 15ms/step - loss: 0.0023 - val_loss: 0.0141
# Epoch 8/100
# 11/11 [==============================] - 0s 14ms/step - loss: 0.0023 - val_loss: 0.0029
# Epoch 9/100
# 11/11 [==============================] - 0s 15ms/step - loss: 0.0016 - val_loss: 0.0052
# Epoch 10/100
# 11/11 [==============================] - 0s 15ms/step - loss: 0.0014 - val_loss: 0.0024
# Epoch 11/100
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0016 - val_loss: 0.0030
# Epoch 12/100
# 11/11 [==============================] - 0s 15ms/step - loss: 0.0012 - val_loss: 0.0169
# Epoch 13/100
# 11/11 [==============================] - 0s 15ms/step - loss: 0.0015 - val_loss: 0.0107
# Epoch 14/100
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0015 - val_loss: 0.0058
# Epoch 15/100
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0014 - val_loss: 0.0035

# %%
# Predict on the test set
predictions = best_model.predict(X_test_minmax)

# Inverse transform predictions and actual values
predictions_original = min_max_scaler.inverse_transform(predictions)
y_test_original = min_max_scaler.inverse_transform(y_test_minmax.reshape(-1, 1))

# Calculate evaluation metrics
mse = mean_squared_error(y_test_original, predictions_original)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_original, predictions_original)

print(f"Evaluation Metrics:\nMSE: {mse:.4f}, RMSE: {rmse:.4f}, MAE: {mae:.4f}")
# Out:
# 3/3 [==============================] - 0s 4ms/step
# Evaluation Metrics:
# MSE: 56.2369, RMSE: 7.4991, MAE: 5.9669

# %%
# Plot actual vs predicted values
plt.figure(figsize=(12, 6))
plt.plot(y_test_original, label='Actual Values', color='blue')
plt.plot(predictions_original, label='Predicted Values', color='orange')
plt.title('Actual vs Predicted Values')
plt.xlabel('Time Steps')
plt.ylabel('I-CIP (Original Scale)')
plt.legend()
plt.show()

# %%
# Print the best trial's cross-validation loss
best_trial = tuner.oracle.get_best_trials(num_trials=1)[0]
print(f"Best Cross-Validation Loss: {best_trial.score}")
# Out:
# Best Cross-Validation Loss: 0.0013821017928421497

# %% [markdown]
# ## Attempt to forecast

# %%
# Use the last sequence of the training data for forecasting
last_sequence = X_train_minmax[-1].reshape(1, -1, 1)  # Shape: (1, timesteps, 1)

# Forecast for next 1 day, 1 week, and 1 month
forecast_steps = [1, 5, 20]
forecasts = []

for step in range(max(forecast_steps)):
    next_pred = best_model.predict(last_sequence)  # Shape: (1, 1)
    forecasts.append(next_pred[0][0])  # Append the scalar prediction
    next_pred_reshaped = np.reshape(next_pred, (1, 1, 1))  # Reshape to (1, 1, 1)
    last_sequence = np.append(last_sequence[:, 1:, :], next_pred_reshaped, axis=1)  # Update sequence

# Inverse transform the forecasts
forecasts_original = min_max_scaler.inverse_transform(np.array(forecasts).reshape(-1, 1))

# Print forecasts
print(f"1-Day Forecast: {forecasts_original[0][0]}")
print(f"1-Week Forecast: {forecasts_original[:5].flatten()}")
print(f"1-Month Forecast: {forecasts_original[:20].flatten()}")
# Out:
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1-Day Forecast: 226.24642944335938
# 1-Week Forecast: [226.24643 225.08281 223.48642 222.80455 222.01414]
# 1-Month Forecast: [226.24643 225.08281 223.48642 222.80455 222.01414 220.4818  218.61537
#  217.31387 216.07474 214.68181 213.05527 211.77554 210.4642  209.12775
#  207.89964 206.77635 205.68736 204.63167 203.65344 202.74521]

# %%
# Prepare forecast dates
forecast_dates = pd.date_range(
    start=df.index[-1], periods=max(forecast_steps) + 1, freq='B'
)[1:]

# Plot historical data and forecasts
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['I-CIP'], label='Historical Data', color='blue')
plt.plot(forecast_dates[:1], forecasts_original[:1], 'o', label='1-Day Forecast', color='orange')
plt.plot(forecast_dates[:5], forecasts_original[:5], 'o', label='1-Week Forecast', color='green')
plt.plot(forecast_dates[:20], forecasts_original[:20], '--', label='1-Month Forecast', color='red')
plt.title('Forecast vs Historical Data')
plt.xlabel('Date')
plt.ylabel('I-CIP (Original Scale)')
plt.legend()
plt.show()

# %% [markdown]
# ## GRU?

# %%
# Define the GRU model
gru_model = tf.keras.Sequential([
    GRU(64, return_sequences=True, input_shape=(window_size, 1)),
    Dropout(0.2),
    GRU(128, return_sequences=True),
    Dropout(0.2),
    GRU(64, return_sequences=False),
    Dense(50, activation='relu'),
    Dense(1)  # Output layer
])

# Compile the model
gru_model.compile(optimizer='adam', loss='mse')

# Train the model
gru_history = gru_model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=32,
    validation_data=(X_test, y_test),
    verbose=1,
    callbacks=[early_stopping]
)

# Evaluate the model
gru_loss = gru_model.evaluate(X_test, y_test, verbose=0)
gru_predictions = gru_model.predict(X_test)

# Inverse transform predictions
gru_scaled_predictions = gru_predictions.flatten()
gru_original_predictions = scaler.inverse_transform(gru_scaled_predictions.reshape(-1, 1))
gru_original_y_test = scaler.inverse_transform(y_test.reshape(-1, 1))

# Plot results
plt.figure(figsize=(12, 6))
plt.plot(gru_original_y_test, label='True Values', color='blue')
plt.plot(gru_original_predictions, label='Predicted Values', color='orange')
plt.legend()
plt.title("GRU Model Predictions")
plt.show()

# Calculate error metrics
gru_mse = mean_squared_error(gru_original_y_test, gru_original_predictions)
gru_mae = mean_absolute_error(gru_original_y_test, gru_original_predictions)
gru_rmse = np.sqrt(gru_mse)
print(f"GRU Model Metrics:\nMSE: {gru_mse:.4f}, MAE: {gru_mae:.4f}, RMSE: {gru_rmse:.4f}")
# Out:
# Epoch 1/100
# 11/11 [==============================] - 3s 70ms/step - loss: 0.0170 - val_loss: 0.0779
# Epoch 2/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0045 - val_loss: 0.0057
# Epoch 3/100
# 11/11 [==============================] - 0s 20ms/step - loss: 0.0024 - val_loss: 0.0065
# Epoch 4/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0020 - val_loss: 0.0031
# Epoch 5/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0017 - val_loss: 0.0031
# Epoch 6/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 7/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 8/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0016 - val_loss: 0.0031
# Epoch 9/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0015 - val_loss: 0.0024
# Epoch 10/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0014 - val_loss: 0.0024
# Epoch 11/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0015 - val_loss: 0.0021
# Epoch 12/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0015 - val_loss: 0.0035
# Epoch 13/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0015 - val_loss: 0.0033
# Epoch 14/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 15/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 16/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0013 - val_loss: 0.0023
# Epoch 17/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0012 - val_loss: 0.0021
# Epoch 18/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 19/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0011 - val_loss: 0.0022
# Epoch 20/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0011 - val_loss: 0.0034
# Epoch 21/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 22/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 23/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 24/100
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0010 - val_loss: 0.0033
# Epoch 25/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0011 - val_loss: 0.0050
# Epoch 26/100
# 11/11 [==============================] - 0s 18ms/step - loss: 9.3551e-04 - val_loss: 0.0063
# Epoch 27/100
# 11/11 [==============================] - 0s 18ms/step - loss: 9.6896e-04 - val_loss: 0.0052
# Epoch 28/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0010 - val_loss: 0.0037
# Epoch 29/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0011 - val_loss: 0.0035
# Epoch 30/100
# 11/11 [==============================] - 0s 18ms/step - loss: 8.8623e-04 - val_loss: 0.0043
# Epoch 31/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0010 - val_loss: 0.0027
# Epoch 32/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0010 - val_loss: 0.0084
# Epoch 33/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0012 - val_loss: 0.0017
# 3/3 [==============================] - 1s 4ms/step
# GRU Model Metrics:
# MSE: 26.5452, MAE: 4.1390, RMSE: 5.1522

# %%
# Plot the training and validation loss
plt.figure(figsize=(14, 7))
plt.plot(gru_history.history['loss'], label='Training Loss')
plt.plot(gru_history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Store results
add_model_results('GRU', mse, mae, rmse)

# %%
# Convert the dictionary into a DataFrame for visualization
metrics_df = pd.DataFrame(model_results).T
metrics_df.reset_index(inplace=True)
metrics_df.rename(columns={'index': 'Model'}, inplace=True)

# Define metrics to plot
metrics = ['MSE', 'MAE', 'RMSE']

# Initialize the plot
plt.figure(figsize=(16, 8))

# Plot each metric
for i, metric in enumerate(metrics, 1):
    plt.subplot(1, len(metrics), i)
    sns.barplot(data=metrics_df, x='Model', y=metric, palette='husl')
    plt.title(f'{metric} Comparison')
    plt.xlabel('Model')
    plt.ylabel(metric)
    plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
metrics_df
# Out:
#                  Model        MSE       MAE      RMSE
# 0    Linear Regression   0.003700  0.046900  0.061200
# 1               LSTM 1   0.000417  0.019428  0.020417
# 2     LSTM (7) min-max   0.000417  0.019428  0.020417
# 3  LSTM (8) std scaler   0.000417  0.019428  0.020417
# 4             LSTM (5)  43.141875  5.445642  6.568247
# 5     Complex LSTM (6)  43.141875  5.445642  6.568247
# 6                  GRU  43.141875  5.445642  6.568247

# %% [markdown]
# ## Plotting LSTM results

# %%
# Filter specific SARIMA models with normalized values
models_to_plot = ['LSTM 1', 
                  'LSTM (7) min-max', 
                  'LSTM (8) std scaler',
                 ]

filtered_df = metrics_df[metrics_df['Model'].isin(models_to_plot)]

# Metrics to plot
metrics_to_plot = ['MSE', 'MAE', 'RMSE']

# Plot each metric separately
fig, axes = plt.subplots(1, len(metrics_to_plot), figsize=(20, 10), sharey=False)

for i, metric in enumerate(metrics_to_plot):
    sns.barplot(
        data=filtered_df,
        x='Model',
        y=metric,
        ax=axes[i],
        palette='husl'
    )
    axes[i].set_title(f'{metric} Comparison')
    axes[i].set_xlabel('Model')
    axes[i].set_ylabel(metric)
    axes[i].tick_params(axis='x', rotation=45)  # Rotate labels

# Adjust layout
plt.tight_layout()
plt.show()
